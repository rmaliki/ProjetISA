# %% [markdown]
# #  Preping data and intervariable correlations

# %%
### Libraries for data exploration ###

import os
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import linear_model
import matplotlib.pyplot as plt
# %matplotlib inline

os.chdir(b"C:\Users\EDDAHABI\Documents\GitHub\ProjetISA")
df = pd.read_csv('Code +Data/TrainSample.csv' ,sep=';' , decimal=',')
df.head()
# Out:
#    API    Surf_X    Surf_Y Date_Drilling Date_Completion Date_Production  \
# 0  661  0.429600 -0.193201    01/06/2013      21/03/2014      08/05/2014
# 1  523 -0.082672 -0.539854    31/08/2014      17/02/2015      03/08/2015
# 2  703 -0.457415 -0.082104    04/11/2013      08/07/2014      30/07/2014
# 3  473  0.376282 -0.310432    24/11/2011      11/05/2012      13/07/2012
# 4  309 -0.113110 -0.111412    20/11/2014      07/04/2015      23/07/2015
#
#    Lateral_Length (ft)  Depth_TVD_PPLS (ft)  Erosion_PPLS (ft)  \
# 0            -1.124200            -0.214336          -1.262296
# 1             1.286521             0.870034           0.717834
# 2            -0.781945             0.511093           0.592495
# 3            -0.442801             0.025900          -1.093255
# 4             0.258511             0.190913           1.229474
#
#    Pressure_PPLS (PSI)    ...      Min_Rate_Slurry (bpm)  \
# 0            -0.153197    ...                   0.635528
# 1             0.674376    ...                  -1.364776
# 2            -0.937430    ...                   0.667127
# 3             0.164815    ...                   0.033723
# 4            -0.347126    ...                  -0.868364
#
#    ShutInPressure_Fil (KPa)  ShutInPressure_Initial (KPa)  ISIP (KPa)  \
# 0                 -0.067825                      0.069978   -0.253698
# 1                  0.835789                      1.136126    0.995649
# 2                 -0.287786                      0.979602   -0.386425
# 3                 -1.034051                     -1.342103   -1.546778
# 4                  0.923707                      1.470667    0.561383
#
#    Shot_Density (shots/ft)  Shot_Total  Proppant_per_ft (kg/ft)  \
# 0                -1.253690    0.181738                 0.979100
# 1                 0.667339   -0.560750                 1.999634
# 2                -1.253690    0.181738                -0.492791
# 3                -0.293176   -1.303237                -0.295062
# 4                 0.667339   -0.560750                 2.034630
#
#    Stage_Spacing (ft)  GasCum360  OilCum360
# 0           -0.184434  -0.323593  -0.659768
# 1           -1.225036  -0.356343   1.782547
# 2           -0.181300  -1.067145   0.283035
# 3            2.135885  -0.734454  -0.328650
# 4           -1.226546  -0.271119   0.975603
#
# [5 rows x 47 columns]

# %%
df.describe()
# Out:
#               API      Surf_X      Surf_Y  Lateral_Length (ft)  \
# count  460.000000  460.000000  460.000000           460.000000
# mean   408.271739    0.048312   -0.020504            -0.038670
# std    228.391358    0.972776    0.974876             0.982085
# min      1.000000   -2.426259   -2.740075            -2.325205
# 25%    206.750000   -0.377085   -0.631271            -0.723762
# 50%    412.000000    0.149286   -0.034792            -0.394263
# 75%    609.250000    0.511680    0.622794             0.578986
# max    793.000000    2.869421    3.143658             3.480066
#
#        Depth_TVD_PPLS (ft)  Erosion_PPLS (ft)  Pressure_PPLS (PSI)  \
# count           460.000000         460.000000           451.000000
# mean             -0.020932          -0.044322             0.032553
# std               0.947728           0.992127             0.983659
# min              -2.958958          -2.135948            -3.287442
# 25%              -0.675256          -0.854066            -0.596984
# 50%              -0.008885          -0.031200             0.177588
# 75%               0.612669           0.845490             0.659758
# max               3.885516           1.987123             1.862078
#
#        TOC_PPLS (%)  Vcarb_PPLS  Vsand_PPLS     ...      \
# count    460.000000  460.000000  460.000000     ...
# mean       0.027042    0.009838   -0.018139     ...
# std        0.995567    1.032273    1.026098     ...
# min       -2.169983   -3.404962   -2.125431     ...
# 25%       -0.593362   -0.294986   -0.718530     ...
# 50%        0.324258    0.245879   -0.190943     ...
# 75%        0.753375    0.786744    0.512507     ...
# max        1.860650    1.868475    3.326308     ...
#
#        Min_Rate_Slurry (bpm)  ShutInPressure_Fil (KPa)  \
# count             362.000000                332.000000
# mean               -0.000074                 -0.007804
# std                 0.956717                  0.973805
# min                -1.576223                 -6.253073
# 25%                -0.637123                 -0.668154
# 50%                 0.216815                  0.079044
# 75%                 0.489761                  0.669197
# max                13.261381                  3.052486
#
#        ShutInPressure_Initial (KPa)  ISIP (KPa)  Shot_Density (shots/ft)  \
# count                    357.000000  361.000000               362.000000
# mean                       0.043509   -0.001943                 0.053141
# std                        1.032365    1.074640                 1.009530
# min                       -2.784977   -2.916152                -1.693075
# 25%                       -0.622318   -0.427222                -1.163446
# 50%                        0.198764    0.176120                 0.667339
# 75%                        0.788128    0.633616                 0.667339
# max                        2.214658    9.119090                 2.588369
#
#        Shot_Total  Proppant_per_ft (kg/ft)  Stage_Spacing (ft)   GasCum360  \
# count  362.000000               362.000000          363.000000  460.000000
# mean    -0.007765                -0.020633            0.063128   -0.004878
# std      0.797089                 0.987912            1.047143    1.015833
# min     -1.320112                -1.959572           -1.647296   -1.241844
# 25%     -0.560750                -0.533204           -0.384367   -0.670713
# 50%      0.159425                -0.486552           -0.178793   -0.354850
# 75%      0.181738                 0.153346            0.435225    0.443100
# max      3.488558                 4.769556            4.610967    5.366269
#
#         OilCum360
# count  460.000000
# mean    -0.011122
# std      0.986570
# min     -0.846812
# 25%     -0.762137
# 50%     -0.269251
# 75%      0.317948
# max      5.527111
#
# [8 rows x 44 columns]

# %%
# Let's now look at the correlations between variables 

fig = plt.figure(figsize=(10,10))
sns.set(font_scale=1)
sns.heatmap(df.select_dtypes(include=['float64', 'int64']).iloc[:,1:].corr()
, vmax=1, squar=True)

# This will definitely help us when predicting a value of a variable using another one from a correlated variable to the first one (using a linear regression for instance).

# %% [markdown]
# # Data processing - Outliers and missing values

# %%
 dfSep = pd.read_csv('./Seperated_Data/data_all_features.csv')
 dfSep.head()
# Out:
#    API    Surf_X    Surf_Y Date_Drilling Date_Completion Date_Production  \
# 0  661  0.429600 -0.193201    01/06/2013      21/03/2014      08/05/2014
# 1  523 -0.082672 -0.539854    31/08/2014      17/02/2015      03/08/2015
# 2  703 -0.457415 -0.082104    04/11/2013      08/07/2014      30/07/2014
# 3  473  0.376282 -0.310432    24/11/2011      11/05/2012      13/07/2012
# 4  309 -0.113110 -0.111412    20/11/2014      07/04/2015      23/07/2015
#
#    Lateral_Length (ft)  Depth_TVD_PPLS (ft)  Erosion_PPLS (ft)  \
# 0            -1.124200            -0.214336          -1.262296
# 1             1.286521             0.870034           0.717834
# 2            -0.781945             0.511093           0.592495
# 3            -0.442801             0.025900          -1.093255
# 4             0.258511             0.190913           1.229474
#
#    Pressure_PPLS (PSI)    ...      Min_Rate_Slurry (bpm)  \
# 0            -0.153197    ...                   0.635528
# 1             0.674376    ...                  -1.364776
# 2            -0.937430    ...                   0.667127
# 3             0.164815    ...                   0.033723
# 4            -0.347126    ...                  -0.868364
#
#    ShutInPressure_Fil (KPa)  ShutInPressure_Initial (KPa)  ISIP (KPa)  \
# 0                 -0.067825                      0.069978   -0.253698
# 1                  0.835789                      1.136126    0.995649
# 2                 -0.287786                      0.979602   -0.386425
# 3                 -1.034051                     -1.342103   -1.546778
# 4                  0.923707                      1.470667    0.561383
#
#    Shot_Density (shots/ft)  Shot_Total  Proppant_per_ft (kg/ft)  \
# 0                -1.253690    0.181738                 0.979100
# 1                 0.667339   -0.560750                 1.999634
# 2                -1.253690    0.181738                -0.492791
# 3                -0.293176   -1.303237                -0.295062
# 4                 0.667339   -0.560750                 2.034630
#
#    Stage_Spacing (ft)  GasCum360  OilCum360
# 0           -0.184434  -0.323593  -0.659768
# 1           -1.225036  -0.356343   1.782547
# 2           -0.181300  -1.067145   0.283035
# 3            2.135885  -0.734454  -0.328650
# 4           -1.226546  -0.271119   0.975603
#
# [5 rows x 47 columns]

# %%
dfSep.describe()
# Out:
#               API      Surf_X      Surf_Y  Lateral_Length (ft)  \
# count  363.000000  363.000000  363.000000           363.000000
# mean   412.517906    0.341779   -0.290007            -0.087250
# std    230.971062    0.613959    0.730973             1.025575
# min      1.000000   -2.190075   -2.740075            -2.325205
# 25%    210.500000   -0.078105   -0.740311            -0.781012
# 50%    410.000000    0.268618   -0.187632            -0.468937
# 75%    623.500000    0.674888    0.172024             0.538227
# max    793.000000    2.439690    1.707435             3.480066
#
#        Depth_TVD_PPLS (ft)  Erosion_PPLS (ft)  Pressure_PPLS (PSI)  \
# count           363.000000         363.000000           361.000000
# mean              0.077515          -0.206906             0.081390
# std               0.871635           0.977851             0.975618
# min              -2.676638          -2.135948            -3.287442
# 25%              -0.618171          -0.950565            -0.596165
# 50%               0.109385          -0.279313             0.222740
# 75%               0.632283           0.569349             0.686254
# max               3.885516           1.987123             1.862078
#
#        TOC_PPLS (%)  Vcarb_PPLS  Vsand_PPLS     ...      \
# count    363.000000  363.000000  363.000000     ...
# mean       0.265943    0.229862   -0.200148     ...
# std        0.896139    0.894158    0.991819     ...
# min       -2.169983   -3.404962   -2.125431     ...
# 25%       -0.089533   -0.159770   -1.070255     ...
# 50%        0.527322    0.381095   -0.190943     ...
# 75%        0.845329    0.786744    0.336645     ...
# max        1.860650    1.868475    3.326308     ...
#
#        Min_Rate_Slurry (bpm)  ShutInPressure_Fil (KPa)  \
# count             362.000000                332.000000
# mean               -0.000074                 -0.007804
# std                 0.956717                  0.973805
# min                -1.576223                 -6.253073
# 25%                -0.637123                 -0.668154
# 50%                 0.216815                  0.079044
# 75%                 0.489761                  0.669197
# max                13.261381                  3.052486
#
#        ShutInPressure_Initial (KPa)  ISIP (KPa)  Shot_Density (shots/ft)  \
# count                    357.000000  361.000000               362.000000
# mean                       0.043509   -0.001943                 0.053141
# std                        1.032365    1.074640                 1.009530
# min                       -2.784977   -2.916152                -1.693075
# 25%                       -0.622318   -0.427222                -1.163446
# 50%                        0.198764    0.176120                 0.667339
# 75%                        0.788128    0.633616                 0.667339
# max                        2.214658    9.119090                 2.588369
#
#        Shot_Total  Proppant_per_ft (kg/ft)  Stage_Spacing (ft)   GasCum360  \
# count  362.000000               362.000000          363.000000  363.000000
# mean    -0.007765                -0.020633            0.063128   -0.047732
# std      0.797089                 0.987912            1.047143    0.878103
# min     -1.320112                -1.959572           -1.647296   -1.230141
# 25%     -0.560750                -0.533204           -0.384367   -0.662907
# 50%      0.159425                -0.486552           -0.178793   -0.323593
# 75%      0.181738                 0.153346            0.435225    0.449358
# max      3.488558                 4.769556            4.610967    3.560147
#
#         OilCum360
# count  363.000000
# mean    -0.104826
# std      0.898170
# min     -0.846812
# 25%     -0.780778
# 50%     -0.343815
# 75%      0.157602
# max      5.242229
#
# [8 rows x 44 columns]

# %%
# Outliers extracting and replacing methods

def outliers(df,column,factor_iqr):
    #quartiles
    Q1       = np.percentile(df.dropna()[column],25)
    Q3       = np.percentile(df.dropna()[column],75)
    iqr      = Q3-Q1    
    #identifing outliers
    index    = np.logical_or(df[column]< Q1 - factor_iqr*iqr, df[column]> Q3 + factor_iqr*iqr)
    outliers = df[index]
    return outliers

def replace_by_mean(df,column,outliers):
    m                             = np.mean(dfSep[column])
    df.loc[outliers.index,column] = m

# %% [markdown]
# ## Temperature (F)

# %%
# Missing values

dfSep["Temperature (F)"].isnull().sum()
# Out:
# 0

# %%
# Checking distribution of Temperature:

plt.rcParams['figure.figsize'] = (8.0,4.0)
(dfSep["Temperature (F)"]).hist()

# %%
f, (ax1, ax2) = plt.subplots(1,2,figsize=(10,6))
ax1.plot(dfSep["Temperature (F)"], dfSep.OilCum360,'.')
ax1.set_title("OilCum vs Temperature")
ax2.plot(dfSep["Temperature (F)"], dfSep.GasCum360,'.')
ax2.set_title("GasCum vs Temperature")
# Out:
# Text(0.5,1,'GasCum vs Temperature')

# %%
plt.figure(figsize = (10, 6))
f, (ax1, ax2) = plt.subplots(2)
sns.boxplot(dfSep["Temperature (F)"],whis=2,ax=ax1)
ax1.set_title('IQR = 2')
sns.boxplot(dfSep["Temperature (F)"],whis=1.5,ax=ax2)
ax2.set_title('IQR = 1.5')
# Out:
# Text(0.5,1,'IQR = 1.5')

# %%
outliers(dfSep,"Temperature (F)",2)
# Out:
#      API    Surf_X    Surf_Y Date_Drilling Date_Completion Date_Production  \
# 17   250  1.355337 -1.747261    12/07/2013      19/12/2013      22/01/2014
# 45     1  1.292105 -1.633644    26/02/2013      09/05/2013      25/07/2013
# 47   565  1.301594 -1.753181    29/06/2012      19/10/2012      02/03/2013
# 167  409  1.224108 -2.063141    01/03/2012      30/03/2012      03/12/2012
# 234  423  1.241227 -2.073282    31/12/2011      30/03/2012      29/11/2012
# 296   95  1.227731 -1.731122    12/05/2013      01/07/2013      06/09/2013
# 315  357  1.216789 -1.773169    06/03/2013      17/04/2013      02/08/2013
# 327  290  1.301884 -1.607345    26/03/2013      24/04/2013      20/07/2013
#
#      Lateral_Length (ft)  Depth_TVD_PPLS (ft)  Erosion_PPLS (ft)  \
# 17             -1.404850             1.404330          -0.215586
# 45              0.104185             1.251648           0.053982
# 47             -1.327687             1.418586          -0.043403
# 167            -1.295328             1.962448           0.197560
# 234            -1.113621             1.962044           0.170324
# 296             0.123476             1.416381           0.167347
# 315            -1.257991             1.496139           0.177175
# 327            -0.514364             1.220558           0.050063
#
#      Pressure_PPLS (PSI)    ...      Min_Rate_Slurry (bpm)  \
# 17              0.786602    ...                   0.118169
# 45              0.569442    ...                   0.488483
# 47              0.799419    ...                   0.474027
# 167             0.396015    ...                   0.518379
# 234             0.393919    ...                   0.501821
# 296             0.763306    ...                   0.320582
# 315             0.789375    ...                   0.556849
# 327             0.488219    ...                   0.607488
#
#      ShutInPressure_Fil (KPa)  ShutInPressure_Initial (KPa)  ISIP (KPa)  \
# 17                        NaN                     -1.678896   -1.123012
# 45                  -1.371269                     -0.622318   -1.952758
# 47                  -2.003455                     -1.946331   -2.622979
# 167                 -1.514176                     -2.558298   -1.537101
# 234                 -1.747549                     -2.149227   -2.551795
# 296                 -1.171674                     -0.716307   -1.806237
# 315                 -1.680553                     -1.227862   -2.629323
# 327                 -1.565541                     -1.305854   -1.824224
#
#      Shot_Density (shots/ft)  Shot_Total  Proppant_per_ft (kg/ft)  \
# 17                 -1.136871    0.362343                -0.324857
# 45                 -0.773433    0.924226                -0.525905
# 47                  0.667339   -0.560750                -0.465284
# 167                -0.293176   -1.303237                -0.795757
# 234                -0.293176   -1.303237                -1.301776
# 296                -0.773433    0.924226                -0.577299
# 315                 0.187082    2.409201                -0.469974
# 327                 0.187082    2.409201                -0.519639
#
#      Stage_Spacing (ft)  GasCum360  OilCum360
# 17            -0.286218  -1.075482  -0.444920
# 45             0.492295  -0.808820  -0.201637
# 47             2.392051  -1.130963  -0.390576
# 167            1.836173  -1.161723  -0.198477
# 234            2.146953  -1.195799  -0.446816
# 296           -0.146234  -0.878078  -0.158667
# 315           -0.152256  -1.079352  -0.410797
# 327           -0.110520  -0.755285  -0.256612
#
# [8 rows x 47 columns]

# %% [markdown]
# ## Temp_Anomaly (F)

# %%
# Missing values

dfSep["Temp_Anomaly (F)"].isnull().sum()
# Out:
# 0

# %%
# Checking distribution of Temp_Anomaly:

plt.rcParams['figure.figsize'] = (8.0,4.0)
(dfSep["Temp_Anomaly (F)"]).hist()

# %%
f, (ax1, ax2) = plt.subplots(1,2,figsize=(10,6))
ax1.plot(dfSep["Temp_Anomaly (F)"], dfSep.OilCum360,'.')
ax1.set_title("OilCum vs Temp_Anomaly")
ax2.plot(dfSep["Temp_Anomaly (F)"], dfSep.GasCum360,'.')
ax2.set_title("GasCum vs Temp_Anomaly ")
# Out:
# Text(0.5,1,'GasCum vs Temp_Anomaly ')

# %%
plt.figure(figsize = (10, 6))
f, (ax1, ax2) = plt.subplots(2)
sns.boxplot(dfSep["Temp_Anomaly (F)"],whis=2,ax=ax1)
ax1.set_title('IQR = 2')
sns.boxplot(dfSep["Temp_Anomaly (F)"],whis=1.5,ax=ax2)
ax2.set_title('IQR = 1.5')
# Out:
# Text(0.5,1,'IQR = 1.5')

# %%
outliers(dfSep,"Temp_Anomaly (F)",2)
# Out:
#      API    Surf_X    Surf_Y Date_Drilling Date_Completion Date_Production  \
# 16   361  0.992658 -1.282477    10/05/2014      03/11/2014      20/01/2015
# 17   250  1.355337 -1.747261    12/07/2013      19/12/2013      22/01/2014
# 27    50  1.086899 -1.622292    22/05/2014      24/10/2014      14/01/2015
# 45     1  1.292105 -1.633644    26/02/2013      09/05/2013      25/07/2013
# 46   550  1.176209 -1.492107    28/03/2013      14/04/2013      06/08/2013
# 47   565  1.301594 -1.753181    29/06/2012      19/10/2012      02/03/2013
# 55   736  1.726695 -1.052039    16/03/2013      06/05/2013      07/03/2014
# 62    81  1.009601 -1.298381    07/08/2012      15/10/2012      31/12/2012
# 72   742  1.189746 -1.388044    13/11/2014      24/01/2015      15/04/2015
# 90   277  1.913070 -1.574677    30/04/2014      12/09/2014      07/11/2014
# 111  685  1.145356 -1.831687    22/01/2013      09/03/2013      22/04/2013
# 113   31  1.114160 -1.501348    11/02/2013      06/03/2013      17/04/2013
# 130  307  1.775030 -1.383179    29/03/2013      10/05/2013      06/03/2014
# 163  541  1.157762 -0.405077    23/08/2013      22/02/2014      24/05/2014
# 167  409  1.224108 -2.063141    01/03/2012      30/03/2012      03/12/2012
# 214  729  1.112406 -1.484721    31/07/2014      12/12/2014      10/04/2015
# 216   44  1.060801 -1.658360    12/07/2012      13/10/2012      27/12/2012
# 234  423  1.241227 -2.073282    31/12/2011      30/03/2012      29/11/2012
# 291  198  1.048966 -1.675125    15/04/2014      25/10/2014      18/01/2015
# 296   95  1.227731 -1.731122    12/05/2013      01/07/2013      06/09/2013
# 298  395  1.290995 -1.184862    21/12/2012      02/03/2013      26/05/2013
# 299  528  1.838553 -1.271672    14/08/2012      20/03/2013      26/02/2014
# 315  357  1.216789 -1.773169    06/03/2013      17/04/2013      02/08/2013
# 318  238  1.690174 -1.350628    01/05/2012      24/06/2012      13/02/2014
# 326  624  0.946950 -1.636028    29/06/2012      30/09/2012      11/12/2012
# 327  290  1.301884 -1.607345    26/03/2013      24/04/2013      20/07/2013
# 338  205  1.244196 -1.304986    22/09/2011      07/11/2011      12/04/2012
# 339  293  0.927267 -1.318917    13/08/2014      15/11/2014      08/03/2015
#
#      Lateral_Length (ft)  Depth_TVD_PPLS (ft)  Erosion_PPLS (ft)  \
# 16              0.126587             1.033214           0.508173
# 17             -1.404850             1.404330          -0.215586
# 27              0.043201             1.401069           0.369352
# 45              0.104185             1.251648           0.053982
# 46             -0.735274             1.114680           0.480374
# 47             -1.327687             1.418586          -0.043403
# 55             -0.433467             0.409129           0.116984
# 62             -0.735896             1.038867           0.538884
# 72              0.465731             0.996255           0.625033
# 90             -0.506274             0.952028           0.823053
# 111            -0.646910             1.670345           0.281329
# 113            -0.607706             1.190245           0.477195
# 130            -0.493828             0.832081           0.180457
# 163            -0.481383            -0.492369           1.797911
# 167            -1.295328             1.962448           0.197560
# 214            -0.355682             1.171703           0.496332
# 216             0.309538             1.493312           0.354366
# 234            -1.113621             1.962044           0.170324
# 291             0.849679             1.536949           0.349967
# 296             0.123476             1.416381           0.167347
# 298            -0.735896             0.806799           0.946645
# 299            -1.294706             0.628804           0.286275
# 315            -1.257991             1.496139           0.177175
# 318            -0.167753             0.864941          -0.088229
# 326            -0.867820             1.599904           0.313690
# 327            -0.514364             1.220558           0.050063
# 338            -0.964274             0.909851           0.663299
# 339            -0.254872             1.154404           0.249172
#
#      Pressure_PPLS (PSI)    ...      Min_Rate_Slurry (bpm)  \
# 16              0.281561    ...                  -0.843141
# 17              0.786602    ...                   0.118169
# 27              0.713677    ...                  -1.088667
# 45              0.569442    ...                   0.488483
# 46              0.276190    ...                   0.539077
# 47              0.799419    ...                   0.474027
# 55             -2.033299    ...                   0.651838
# 62              0.248897    ...                   0.243790
# 72             -0.129289    ...                  -0.642281
# 90              0.126780    ...                  -0.029738
# 111             0.720926    ...                   0.713489
# 113             0.440447    ...                   0.631663
# 130            -0.402607    ...                   0.490187
# 163            -1.982163    ...                   0.538084
# 167             0.396015    ...                   0.518379
# 214             0.402041    ...                  -0.417373
# 216             0.779113    ...                   0.332100
# 234             0.393919    ...                   0.501821
# 291             0.801188    ...                  -0.710737
# 296             0.763306    ...                   0.320582
# 298            -1.376445    ...                   0.711006
# 299            -0.857517    ...                   0.591070
# 315             0.789375    ...                   0.556849
# 318            -0.596165    ...                   0.449513
# 326             1.025160    ...                   0.464565
# 327             0.488219    ...                   0.607488
# 338            -0.654330    ...                  -0.218292
# 339             0.615337    ...                  -0.843951
#
#      ShutInPressure_Fil (KPa)  ShutInPressure_Initial (KPa)  ISIP (KPa)  \
# 16                   0.946055                      0.368202    0.556566
# 17                        NaN                     -1.678896   -1.123012
# 27                   0.937169                      0.492347    0.842684
# 45                  -1.371269                     -0.622318   -1.952758
# 46                  -1.186651                     -0.771964   -1.785441
# 47                  -2.003455                     -1.946331   -2.622979
# 55                  -1.684559                     -1.721357   -2.376652
# 62                   0.093793                     -1.357932    0.044760
# 72                   1.460048                      0.988143    0.701610
# 90                  -1.310839                     -1.457747   -2.243103
# 111                  0.246774                     -0.547736    0.250500
# 113                 -0.667502                     -0.806631   -0.726582
# 130                 -1.674395                     -1.677600   -1.720985
# 163                       NaN                      2.091678    0.663034
# 167                 -1.514176                     -2.558298   -1.537101
# 214                  1.338782                      0.355661    0.609435
# 216                 -0.100374                     -0.932726   -0.027847
# 234                 -1.747549                     -2.149227   -2.551795
# 291                  0.624419                      0.453377    0.393393
# 296                 -1.171674                     -0.716307   -1.806237
# 298                 -0.112019                     -0.151794    0.348551
# 299                 -2.094708                     -2.304350   -2.916152
# 315                 -1.680553                     -1.227862   -2.629323
# 318                 -1.383881                     -1.574115   -2.073695
# 326                 -1.063210                     -1.691911   -1.318446
# 327                 -1.565541                     -1.305854   -1.824224
# 338                  0.686199                     -0.441132    0.419538
# 339                  1.422568                      1.356033    0.566460
#
#      Shot_Density (shots/ft)  Shot_Total  Proppant_per_ft (kg/ft)  \
# 16                  1.605516    0.164471                 2.095524
# 17                 -1.136871    0.362343                -0.324857
# 27                  0.667339    0.163629                 1.947916
# 45                 -0.773433    0.924226                -0.525905
# 46                 -1.253690    0.181738                -0.516878
# 47                  0.667339   -0.560750                -0.465284
# 55                 -0.773433    0.924226                -0.532775
# 62                  0.667339   -0.560750                 0.941815
# 72                  0.667339   -0.560750                -0.481070
# 90                  0.667339   -0.560750                -0.620011
# 111                -1.253690    0.181738                -0.511727
# 113                 0.187082    2.409201                -0.529653
# 130                -0.773433    0.924226                -0.634407
# 163                -1.253690    0.181738                -0.479817
# 167                -0.293176   -1.303237                -0.795757
# 214                 0.692616   -0.541210                 2.126845
# 216                 0.667339   -0.560750                -0.520607
# 234                -0.293176   -1.303237                -1.301776
# 291                 1.627854    0.181738                 2.103894
# 296                -0.773433    0.924226                -0.577299
# 298                 0.467232   -0.560750                -0.505535
# 299                -1.253690    0.181738                -0.477409
# 315                 0.187082    2.409201                -0.469974
# 318                -0.293176   -1.320112                -1.058869
# 326                -0.293176    0.924226                -0.503627
# 327                 0.187082    2.409201                -0.519639
# 338                -0.998554    0.576185                -1.538300
# 339                -1.204433   -0.560750                 2.021363
#
#      Stage_Spacing (ft)  GasCum360  OilCum360
# 16            -1.238962  -0.588088  -0.343815
# 17            -0.286218  -1.075482  -0.444920
# 27            -1.205387  -0.659690  -0.126440
# 45             0.492295  -0.808820  -0.201637
# 46             1.030130  -0.944860  -0.319171
# 47             2.392051  -1.130963  -0.390576
# 55            -0.174536   0.522453  -0.846812
# 62             2.205136  -0.798361  -0.500528
# 72            -0.237445  -0.223178  -0.503688
# 90            -0.104694   0.015422  -0.592154
# 111            1.130885  -1.019978  -0.192790
# 113           -0.177740  -0.903663  -0.209851
# 130           -0.095731   0.035235  -0.818376
# 163           -0.207317   1.353638  -0.846812
# 167            1.836173  -1.161723  -0.198477
# 214           -1.246987  -0.561508  -0.356454
# 216            2.221456  -0.656019   0.150967
# 234            2.146953  -1.195799  -0.446816
# 291           -1.242418  -0.506314   0.257759
# 296           -0.146234  -0.878078  -0.158667
# 298            1.029420  -0.639478  -0.660400
# 299            0.970244  -0.129197  -0.846180
# 315           -0.152256  -1.079352  -0.410797
# 318            2.056777  -0.665572  -0.736861
# 326            0.878997  -0.947270  -0.217434
# 327           -0.110520  -0.755285  -0.256612
# 338            1.422366  -0.393847  -0.551712
# 339           -1.243689  -0.591958  -0.266723
#
# [28 rows x 47 columns]

# %% [markdown]
# ## S3Tect_PPLS (PSI)

# %%
# Missing values 

dfSep["S3Tect_PPLS (PSI)"].isnull().sum()
# Out:
# 0

# %%
f, (ax1, ax2) = plt.subplots(1,2,figsize=(10,6))
ax1.plot(dfSep["S3Tect_PPLS (PSI)"], dfSep.OilCum360,'.')
ax1.set_title("OilCum vs S3Tect_PPLS (PSI)")
ax2.plot(dfSep["S3Tect_PPLS (PSI)"], dfSep.GasCum360,'.')
ax2.set_title("GasCum vs S3Tect_PPLS (PSI)")
# Out:
# Text(0.5,1,'GasCum vs S3Tect_PPLS (PSI)')

# %%
# Checking distribution of S3Tect_PPLS:

plt.rcParams['figure.figsize'] = (8.0,4.0)
(dfSep["S3Tect_PPLS (PSI)"]).hist(bins=20)

# %%
plt.figure(figsize = (16, 6))
f, (ax1, ax2) = plt.subplots(2)
sns.boxplot(dfSep["S3Tect_PPLS (PSI)"],whis=1.5,ax=ax1)
ax1.set_title('IQR = 1.5')
sns.boxplot(dfSep["S3Tect_PPLS (PSI)"],whis=2,ax=ax2)
ax2.set_title('IQR = 2')
# Out:
# Text(0.5,1,'IQR = 2')

# %%
o3 = outliers(dfSep,"S3Tect_PPLS (PSI)",2)
o3[["API","S3Tect_PPLS (PSI)"]]
# Out:
#      API  S3Tect_PPLS (PSI)
# 35   108          -1.900288
# 39   185           2.368697
# 56   255          -2.336294
# 90   277           2.421440
# 96   629           2.386987
# 104  143           2.361581
# 130  307           2.214436
# 195  562          -1.891932
# 218  118           2.469545
# 227  169          -1.842923
# 241  585           2.227520
# 247  271          -1.866907
# 270   30          -1.898261
# 299  528           2.294301
# 314  440          -1.838656

# %% [markdown]
# We replace outliers by mean:

# %%
replace_by_mean(dfSep,"S3Tect_PPLS (PSI)",o3)

# %% [markdown]
# ## S3_contrast_PPLS (PSI)

# %%
# Missing values

dfSep["S3_contrast_PPLS (PSI)"].isnull().sum()
# Out:
# 0

# %%
f, (ax1, ax2) = plt.subplots(1,2,figsize=(10,6))
ax1.plot(dfSep["S3_contrast_PPLS (PSI)"], dfSep.OilCum360,'.')
ax1.set_title("OilCum vs S3_contrast_PPLS (PSI)")
ax2.plot(dfSep["S3_contrast_PPLS (PSI)"], dfSep.GasCum360,'.')
ax2.set_title("GasCum vs S3_contrast_PPLS (PSI)")
# Out:
# Text(0.5,1,'GasCum vs S3_contrast_PPLS (PSI)')

# %%
# Checking distribution of S3_contrast_PPLS (PSI):

plt.rcParams['figure.figsize'] = (8.0,4.0)
(dfSep["S3_contrast_PPLS (PSI)"]).hist()

# %%
sns.boxplot(dfSep["S3_contrast_PPLS (PSI)"],whis=2)

# %% [markdown]
# No outliers and no clear dependence between this variable and oil/gas.

# %% [markdown]
# ## Heat_Flow (W/m2)

# %%
# Missing values

dfSep["Heat_Flow (W/m2)"].isnull().sum()
# Out:
# 0

# %%
f, (ax1, ax2) = plt.subplots(1,2,figsize=(10,6))
ax1.plot(dfSep["Heat_Flow (W/m2)"], dfSep.OilCum360,'.')
ax1.set_title("OilCum vs Heat_Flow")
ax2.plot(dfSep["Heat_Flow (W/m2)"], dfSep.GasCum360,'.')
ax2.set_title("GasCum vs Heat_Flow")
# Out:
# Text(0.5,1,'GasCum vs Heat_Flow')

# %%
# Checking distribution of Heat_Flow:

plt.rcParams['figure.figsize'] = (8.0,4.0)
(dfSep["Heat_Flow (W/m2)"]).hist()

# %%
plt.figure(figsize = (16, 6))
f, (ax1, ax2) = plt.subplots(2)
sns.boxplot(dfSep["Heat_Flow (W/m2)"],whis=2,ax=ax1)
ax1.set_title('IQR = 2')
sns.boxplot(dfSep["Heat_Flow (W/m2)"],whis=1.5,ax=ax2)
ax2.set_title('IQR = 1.5')
# Out:
# Text(0.5,1,'IQR = 1.5')

# %%
oHF = outliers(dfSep,"Heat_Flow (W/m2)",2)
oHF[["API","Heat_Flow (W/m2)"]]
# Out:
#      API  Heat_Flow (W/m2)
# 17   250         -3.283776
# 27    50         -3.343225
# 45     1         -3.703262
# 46   550         -3.637605
# 47   565         -3.964455
# 62    81         -2.859993
# 72   742         -3.304786
# 111  685         -3.408165
# 113   31         -3.581737
# 167  409         -3.760562
# 214  729         -3.564786
# 216   44         -3.029268
# 234  423         -3.713528
# 291  198         -2.857844
# 296   95         -4.248091
# 315  357         -4.344308
# 327  290         -3.540911

# %% [markdown]
# We replace outliers by mean:

# %%
replace_by_mean(dfSep,"Heat_Flow (W/m2)",oHF)
