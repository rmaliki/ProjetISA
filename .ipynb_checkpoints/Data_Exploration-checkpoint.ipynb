# %%
# First data Exploration (values to predict, correlation ..)
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('TrainSample.csv',sep=';',decimal=',')
df.head()
# Out:
#    API    Surf_X    Surf_Y Date_Drilling Date_Completion Date_Production  \
# 0  661  0.429600 -0.193201    01/06/2013      21/03/2014      08/05/2014
# 1  523 -0.082672 -0.539854    31/08/2014      17/02/2015      03/08/2015
# 2  703 -0.457415 -0.082104    04/11/2013      08/07/2014      30/07/2014
# 3  473  0.376282 -0.310432    24/11/2011      11/05/2012      13/07/2012
# 4  309 -0.113110 -0.111412    20/11/2014      07/04/2015      23/07/2015
#
#    Lateral_Length (ft)  Depth_TVD_PPLS (ft)  Erosion_PPLS (ft)  \
# 0            -1.124200            -0.214336          -1.262296
# 1             1.286521             0.870034           0.717834
# 2            -0.781945             0.511093           0.592495
# 3            -0.442801             0.025900          -1.093255
# 4             0.258511             0.190913           1.229474
#
#    Pressure_PPLS (PSI)    ...      Min_Rate_Slurry (bpm)  \
# 0            -0.153197    ...                   0.635528
# 1             0.674376    ...                  -1.364776
# 2            -0.937430    ...                   0.667127
# 3             0.164815    ...                   0.033723
# 4            -0.347126    ...                  -0.868364
#
#    ShutInPressure_Fil (KPa)  ShutInPressure_Initial (KPa)  ISIP (KPa)  \
# 0                 -0.067825                      0.069978   -0.253698
# 1                  0.835789                      1.136126    0.995649
# 2                 -0.287786                      0.979602   -0.386425
# 3                 -1.034051                     -1.342103   -1.546778
# 4                  0.923707                      1.470667    0.561383
#
#    Shot_Density (shots/ft)  Shot_Total  Proppant_per_ft (kg/ft)  \
# 0                -1.253690    0.181738                 0.979100
# 1                 0.667339   -0.560750                 1.999634
# 2                -1.253690    0.181738                -0.492791
# 3                -0.293176   -1.303237                -0.295062
# 4                 0.667339   -0.560750                 2.034630
#
#    Stage_Spacing (ft)  GasCum360  OilCum360
# 0           -0.184434  -0.323593  -0.659768
# 1           -1.225036  -0.356343   1.782547
# 2           -0.181300  -1.067145   0.283035
# 3            2.135885  -0.734454  -0.328650
# 4           -1.226546  -0.271119   0.975603
#
# [5 rows x 47 columns]

# %%
df.describe()
# Out:
#               API      Surf_X      Surf_Y  Lateral_Length (ft)  \
# count  460.000000  460.000000  460.000000           460.000000
# mean   408.271739    0.048312   -0.020504            -0.038670
# std    228.391358    0.972776    0.974876             0.982085
# min      1.000000   -2.426259   -2.740075            -2.325205
# 25%    206.750000   -0.377085   -0.631271            -0.723762
# 50%    412.000000    0.149286   -0.034792            -0.394263
# 75%    609.250000    0.511680    0.622794             0.578986
# max    793.000000    2.869421    3.143658             3.480066
#
#        Depth_TVD_PPLS (ft)  Erosion_PPLS (ft)  Pressure_PPLS (PSI)  \
# count           460.000000         460.000000           451.000000
# mean             -0.020932          -0.044322             0.032553
# std               0.947728           0.992127             0.983659
# min              -2.958958          -2.135948            -3.287442
# 25%              -0.675256          -0.854066            -0.596984
# 50%              -0.008885          -0.031200             0.177588
# 75%               0.612669           0.845490             0.659758
# max               3.885516           1.987123             1.862078
#
#        TOC_PPLS (%)  Vcarb_PPLS  Vsand_PPLS     ...      \
# count    460.000000  460.000000  460.000000     ...
# mean       0.027042    0.009838   -0.018139     ...
# std        0.995567    1.032273    1.026098     ...
# min       -2.169983   -3.404962   -2.125431     ...
# 25%       -0.593362   -0.294986   -0.718530     ...
# 50%        0.324258    0.245879   -0.190943     ...
# 75%        0.753375    0.786744    0.512507     ...
# max        1.860650    1.868475    3.326308     ...
#
#        Min_Rate_Slurry (bpm)  ShutInPressure_Fil (KPa)  \
# count             362.000000                332.000000
# mean               -0.000074                 -0.007804
# std                 0.956717                  0.973805
# min                -1.576223                 -6.253073
# 25%                -0.637123                 -0.668154
# 50%                 0.216815                  0.079044
# 75%                 0.489761                  0.669197
# max                13.261381                  3.052486
#
#        ShutInPressure_Initial (KPa)  ISIP (KPa)  Shot_Density (shots/ft)  \
# count                    357.000000  361.000000               362.000000
# mean                       0.043509   -0.001943                 0.053141
# std                        1.032365    1.074640                 1.009530
# min                       -2.784977   -2.916152                -1.693075
# 25%                       -0.622318   -0.427222                -1.163446
# 50%                        0.198764    0.176120                 0.667339
# 75%                        0.788128    0.633616                 0.667339
# max                        2.214658    9.119090                 2.588369
#
#        Shot_Total  Proppant_per_ft (kg/ft)  Stage_Spacing (ft)   GasCum360  \
# count  362.000000               362.000000          363.000000  460.000000
# mean    -0.007765                -0.020633            0.063128   -0.004878
# std      0.797089                 0.987912            1.047143    1.015833
# min     -1.320112                -1.959572           -1.647296   -1.241844
# 25%     -0.560750                -0.533204           -0.384367   -0.670713
# 50%      0.159425                -0.486552           -0.178793   -0.354850
# 75%      0.181738                 0.153346            0.435225    0.443100
# max      3.488558                 4.769556            4.610967    5.366269
#
#         OilCum360
# count  460.000000
# mean    -0.011122
# std      0.986570
# min     -0.846812
# 25%     -0.762137
# 50%     -0.269251
# 75%      0.317948
# max      5.527111
#
# [8 rows x 44 columns]

# %%
#Visualizing distributions of OilCum and GasCum (values to predict)
plt.figure(figsize=(12,8))
plt.subplot(121)
sns.distplot(df.GasCum360,kde=False)
plt.xlabel('Gas Cum')
plt.subplot(122)
sns.distplot(df.OilCum360,kde=False)
plt.xlabel('Oil Cum')
#plt.axis([10,14,0,180])

# %%
#Pour mieux visualiser les correlations entre les variables, on utilise heatmap. 
corr = df.select_dtypes(include = ['float64', 'int64']).iloc[:,1:].corr()
fig = plt.figure(figsize=(15,10))
sns.set(font_scale=1)  
sns.heatmap(corr, vmax=1, square=True)

# %%
correlationG = corr['GasCum360'].sort_values(axis=0,ascending=False).iloc[1:]
correlationO = corr['OilCum360'].sort_values(axis=0,ascending=False).iloc[1:]
print("Pour la variable GasCum :\n",correlationG)

print("Pour la variable GasCum :\n",correlationO)
# Out:
# Pour la variable GasCum :
#  Zone                            0.571040
# Surf_Y                          0.464759
# Lateral_Length (ft)             0.444635
# ShutInPressure_Initial (KPa)    0.436298
# ShutInPressure_Fil (KPa)        0.413869
# ISIP (KPa)                      0.378240
# Temperature (F)                 0.337634
# Temp_Anomaly (F)                0.327720
# Min_Treating_Pressure (KPa)     0.306921
# Nbr_Stages                      0.304499
# Proppant_in_Formation (kg)      0.283659
# Avg_Treating_Pressure (KPa)     0.283176
# Proppant_Designed (kg)          0.279918
# DTs_PPLS (us/ft)                0.267222
# Vcarb_PPLS                      0.253354
# PR_PPLS                         0.230320
# GR_PPLS (API)                   0.177396
# Heat_Flow (W/m2)                0.157747
# Pressure_PPLS (PSI)             0.120171
# Proppant_per_ft (kg/ft)         0.096563
# Max_Treating_pressure (KPa)     0.079698
# DT_PPLS (us/ft)                 0.061891
# Shot_Density (shots/ft)         0.059898
# Avg_Breakdown_Pressure (KPa)    0.046852
# Shot_Total                      0.019059
# Frac_Gradient (PSI/ft)          0.011320
# Erosion_PPLS (ft)              -0.044073
# S3_contrast_PPLS (PSI)         -0.052962
# YM_PPLS (PSI)                  -0.058974
# Min_Rate_Slurry (bpm)          -0.082929
# Surf_X                         -0.090891
# Avg_Rate_Slurry (bpm)          -0.125699
# Vsand_PPLS                     -0.139425
# Res_PPLS (Ohmm)                -0.172116
# Max_Rate_Slurry (bpm)          -0.174108
# S3Tect_PPLS (PSI)              -0.220270
# OilCum360                      -0.237945
# Stage_Spacing (ft)             -0.274763
# Vclay_PPLS                     -0.289424
# TOC_PPLS (%)                   -0.318585
# RHOB_PPLS (g/cc)               -0.393667
# Depth_TVD_PPLS (ft)            -0.648733
# Name: GasCum360, dtype: float64
# Pour la variable GasCum :
#  Proppant_Designed (kg)          0.579986
# Proppant_in_Formation (kg)      0.566545
# Nbr_Stages                      0.561637
# Proppant_per_ft (kg/ft)         0.449341
# S3_contrast_PPLS (PSI)          0.378867
# Depth_TVD_PPLS (ft)             0.315282
# Vclay_PPLS                      0.314919
# Erosion_PPLS (ft)               0.269249
# RHOB_PPLS (g/cc)                0.266131
# Lateral_Length (ft)             0.259824
# ShutInPressure_Initial (KPa)    0.156128
# Max_Treating_pressure (KPa)     0.149713
# Shot_Density (shots/ft)         0.109103
# Vsand_PPLS                      0.089166
# YM_PPLS (PSI)                   0.087063
# Avg_Treating_Pressure (KPa)     0.082437
# ShutInPressure_Fil (KPa)        0.078789
# Frac_Gradient (PSI/ft)          0.077939
# Surf_Y                          0.068438
# Heat_Flow (W/m2)                0.063840
# TOC_PPLS (%)                    0.035716
# ISIP (KPa)                      0.024597
# Max_Rate_Slurry (bpm)           0.001064
# GR_PPLS (API)                  -0.014411
# Shot_Total                     -0.039535
# Min_Treating_Pressure (KPa)    -0.055782
# Temp_Anomaly (F)               -0.070211
# Avg_Rate_Slurry (bpm)          -0.081764
# Pressure_PPLS (PSI)            -0.092179
# Temperature (F)                -0.102528
# Res_PPLS (Ohmm)                -0.110681
# Min_Rate_Slurry (bpm)          -0.125303
# Vcarb_PPLS                     -0.206901
# Avg_Breakdown_Pressure (KPa)   -0.224735
# PR_PPLS                        -0.226452
# GasCum360                      -0.237945
# S3Tect_PPLS (PSI)              -0.238030
# DTs_PPLS (us/ft)               -0.264372
# Stage_Spacing (ft)             -0.345143
# Surf_X                         -0.422197
# DT_PPLS (us/ft)                -0.490076
# Zone                           -0.572574
# Name: OilCum360, dtype: float64

# %%
#Variables Toufik
df.describe().iloc[:,18:35]
# Out:
#        Temperature (F)  Temp_Anomaly (F)  S3Tect_PPLS (PSI)  \
# count       460.000000        460.000000         460.000000
# mean         -0.027377         -0.047119           0.025656
# std           1.065380          1.090981           1.006216
# min          -3.997708         -4.533532          -2.556728
# 25%          -0.625253         -0.415127          -0.643375
# 50%          -0.028060          0.039883           0.224793
# 75%           0.594067          0.511212           0.656358
# max           2.418891          2.538358           2.469545
#
#        S3_contrast_PPLS (PSI)  Heat_Flow (W/m2)        Zone  Nbr_Stages  \
# count              460.000000        460.000000  460.000000  363.000000
# mean                -0.033985         -0.063158    0.004835   -0.048196
# std                  1.021623          1.079007    0.940416    0.990937
# min                 -2.719330         -4.344308   -2.542416   -1.305436
# 25%                 -0.682062         -0.566193   -0.457477   -0.757870
# 50%                 -0.100264          0.060887   -0.457477   -0.356321
# 75%                  0.832426          0.587930    1.106227    0.519785
# max                  1.684259          2.515964    2.669931    2.929077
#
#        Frac_Gradient (PSI/ft)  Proppant_Designed (kg)  \
# count              355.000000              363.000000
# mean                 0.019048               -0.032791
# std                  1.286883                0.999613
# min                 -0.794076               -1.509136
# 25%                 -0.148146               -0.726603
# 50%                  0.003846               -0.450393
# 75%                  0.111784                0.462816
# max                 23.781014                3.209552
#
#        Proppant_in_Formation (kg)  Avg_Breakdown_Pressure (KPa)  \
# count                  362.000000                    361.000000
# mean                    -0.030408                     -0.006015
# std                      0.998820                      1.017355
# min                     -1.519976                     -2.741104
# 25%                     -0.725324                     -0.701698
# 50%                     -0.437994                     -0.142323
# 75%                      0.480903                      0.645923
# max                      3.212776                      2.968671
#
#        Avg_Treating_Pressure (KPa)  Max_Treating_pressure (KPa)  \
# count                   363.000000                   362.000000
# mean                     -0.029595                    -0.073869
# std                       0.994565                     0.749684
# min                      -4.641543                    -3.833633
# 25%                      -0.468265                    -0.362909
# 50%                       0.096051                     0.077879
# 75%                       0.633773                     0.388579
# max                       1.946600                     1.652424
#
#        Min_Treating_Pressure (KPa)  Avg_Rate_Slurry (bpm)  \
# count                   362.000000             363.000000
# mean                     -0.045175               0.035797
# std                       1.083354               0.964642
# min                      -7.938938              -2.877936
# 25%                      -0.473001              -0.596597
# 50%                       0.102667               0.113523
# 75%                       0.600416               0.770679
# max                       3.591486               3.813211
#
#        Max_Rate_Slurry (bpm)  Min_Rate_Slurry (bpm)
# count             361.000000             362.000000
# mean                0.048529              -0.000074
# std                 0.991292               0.956717
# min                -3.264990              -1.576223
# 25%                -0.579531              -0.637123
# 50%                 0.324590               0.216815
# 75%                 0.740349               0.489761
# max                 3.436429              13.261381

# %%
#Correlations set3,set3/set3,set4
df.iloc[:,9:19]
